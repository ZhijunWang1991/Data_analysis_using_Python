# %%
import pandas as pd
import numpy as np

# %%
ride_sharing = pd.read_csv("ride_sharing_new.csv")

# %%
# Print the information of ride_sharing
print(ride_sharing.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25760 entries, 0 to 25759
# Data columns (total 10 columns):
# Unnamed: 0         25760 non-null int64
# duration           25760 non-null object
# station_A_id       25760 non-null int64
# station_A_name     25760 non-null object
# station_B_id       25760 non-null int64
# station_B_name     25760 non-null object
# bike_id            25760 non-null int64
# user_type          25760 non-null int64
# user_birth_year    25760 non-null int64
# user_gender        25760 non-null object
# dtypes: int64(6), object(4)
# memory usage: 2.0+ MB
# None

# %%
# Print summary statistics of user_type column
print(ride_sharing['user_type'].describe())
# Out:
# count    25760.000000
# mean         2.008385
# std          0.704541
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          3.000000
# Name: user_type, dtype: float64

# %%
# Convert user_type from integer to category
ride_sharing['user_type_cat'] = ride_sharing['user_type'].astype('category')

# %%
# Write an assert statement confirming the change
assert ride_sharing['user_type_cat'].dtype == 'category'

# %%
# Print new summary statistics 
print(ride_sharing['user_type_cat'].describe())
# Out:
# count     25760
# unique        3
# top           2
# freq      12972
# Name: user_type_cat, dtype: int64

# %%
# Print the information of ride_sharing
print(ride_sharing.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25760 entries, 0 to 25759
# Data columns (total 11 columns):
# Unnamed: 0         25760 non-null int64
# duration           25760 non-null object
# station_A_id       25760 non-null int64
# station_A_name     25760 non-null object
# station_B_id       25760 non-null int64
# station_B_name     25760 non-null object
# bike_id            25760 non-null int64
# user_type          25760 non-null int64
# user_birth_year    25760 non-null int64
# user_gender        25760 non-null object
# user_type_cat      25760 non-null category
# dtypes: category(1), int64(6), object(4)
# memory usage: 2.0+ MB
# None

# %%
# Strip duration of minutes
ride_sharing['duration_trim'] = ride_sharing['duration'].str.strip('minutes') 

# Convert duration to integer
ride_sharing['duration_time'] = ride_sharing['duration_trim'].astype('int')

# Write an assert statement making sure of conversion
assert ride_sharing['duration_time'].dtype == 'int'

# Print formed columns and calculate average ride duration 
print(ride_sharing[['duration','duration_trim','duration_time']])
print(ride_sharing['duration_time'].mean())
# Out:
#           duration duration_trim  duration_time
# 0       12 minutes           12              12
# 1       24 minutes           24              24
# 2        8 minutes            8               8
# 3        4 minutes            4               4
# 4       11 minutes           11              11
# 5       10 minutes           10              10
# 6       16 minutes           16              16
# 7        9 minutes            9               9
# 8       21 minutes           21              21
# 9        5 minutes            5               5
# 10      19 minutes           19              19
# 11       6 minutes            6               6
# 12       7 minutes            7               7
# 13     187 minutes          187             187
# 14      13 minutes           13              13
# 15       4 minutes            4               4
# 16      32 minutes           32              32
# 17       5 minutes            5               5
# 18      16 minutes           16              16
# 19      17 minutes           17              17
# 20      16 minutes           16              16
# 21      11 minutes           11              11
# 22      10 minutes           10              10
# 23       3 minutes            3               3
# 24      11 minutes           11              11
# 25       3 minutes            3               3
# 26      12 minutes           12              12
# 27       7 minutes            7               7
# 28       5 minutes            5               5
# 29       6 minutes            6               6
# ...            ...           ...            ...
# 25730    1 minutes            1               1
# 25731   12 minutes           12              12
# 25732   24 minutes           24              24
# 25733   21 minutes           21              21
# 25734    1 minutes            1               1
# 25735    2 minutes            2               2
# 25736   13 minutes           13              13
# 25737   13 minutes           13              13
# 25738   19 minutes           19              19
# 25739   18 minutes           18              18
# 25740   18 minutes           18              18
# 25741   12 minutes           12              12
# 25742    6 minutes            6               6
# 25743   10 minutes           10              10
# 25744    4 minutes            4               4
# 25745   17 minutes           17              17
# 25746    4 minutes            4               4
# 25747   31 minutes           31              31
# 25748   31 minutes           31              31
# 25749   15 minutes           15              15
# 25750   15 minutes           15              15
# 25751   15 minutes           15              15
# 25752   15 minutes           15              15
# 25753    9 minutes            9               9
# 25754    9 minutes            9               9
# 25755   11 minutes           11              11
# 25756   10 minutes           10              10
# 25757   14 minutes           14              14
# 25758   14 minutes           14              14
# 25759   29 minutes           29              29
#
# [25760 rows x 3 columns]
# 11.389052795031056

# %%
# Convert tire_sizes to integer
ride_sharing['tire_sizes'] = ride_sharing['tire_sizes'].astype('int')

# Set all values above 27 to 27
ride_sharing.loc[ride_sharing['tire_sizes'] > 27, 'tire_sizes'] = 27

# Reconvert tire_sizes back to categorical
ride_sharing['tire_sizes'] = ride_sharing['tire_sizes'].astype('category')

# Print tire size description
print(ride_sharing['tire_sizes'].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tire_sizes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-a2367fb8d266> in <module>
#       1 # Convert tire_sizes to integer
# ----> 2 ride_sharing['tire_sizes'] = ride_sharing['tire_sizes'].astype('int')
#       3
#       4 # Set all values above 27 to 27
#       5 ride_sharing.loc[ride_sharing['tire_sizes'] > 27, 'tire_sizes'] = 27
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tire_sizes'

# %%
ride_sharing['tire_sizes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tire_sizes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-8753a18ca0ce> in <module>
# ----> 1 ride_sharing['tire_sizes']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tire_sizes'

# %%
ride_sharing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25760 entries, 0 to 25759
# Data columns (total 13 columns):
# Unnamed: 0         25760 non-null int64
# duration           25760 non-null object
# station_A_id       25760 non-null int64
# station_A_name     25760 non-null object
# station_B_id       25760 non-null int64
# station_B_name     25760 non-null object
# bike_id            25760 non-null int64
# user_type          25760 non-null int64
# user_birth_year    25760 non-null int64
# user_gender        25760 non-null object
# user_type_cat      25760 non-null category
# duration_trim      25760 non-null object
# duration_time      25760 non-null int32
# dtypes: category(1), int32(1), int64(6), object(5)
# memory usage: 2.3+ MB

# %%
##Text and categorical data problems

# %%
airlines = pd.read_csv('airlines_final.csv')
categories = pd.read_csv('categories.csv')

# %%
# Print categories DataFrame
print(categories)
# Out:
#        cleanliness            safety          satisfaction
# 0            Clean           Neutral        Very satisfied
# 1         Average          Very safe               Neutral
# 2   Somewhat clean     Somewhat safe    Somewhat satisfied
# 3  Somewhat dirty        Very unsafe  Somewhat unsatisfied
# 4           Dirty   Somewhat unsafe       Very unsatisfied

# %%
# Print unique values of survey columns in airlines
print('Cleanliness: ', airlines['cleanliness'].unique(), "\n")
print('Safety: ', airlines['safety'].unique(), "\n")
print('Satisfaction: ', airlines['satisfaction'].unique(), "\n")
# Out:
# Cleanliness:  ['Clean' 'Average' 'Somewhat clean' 'Somewhat dirty' 'Dirty']
#
# Safety:  ['Neutral' 'Very safe' 'Somewhat safe' 'Very unsafe' 'Somewhat unsafe']
#
# Satisfaction:  ['Very satisfied' 'Neutral' 'Somewhat satsified' 'Somewhat unsatisfied'
#  'Very unsatisfied']

# %%
airlines
# Out:
#       Unnamed: 0    id        day           airline           destination  \
# 0              0  1351    Tuesday       UNITED INTL                KANSAI
# 1              1   373     Friday            ALASKA     SAN JOSE DEL CABO
# 2              2  2820   Thursday             DELTA           LOS ANGELES
# 3              3  1157    Tuesday         SOUTHWEST           LOS ANGELES
# 4              4  2992  Wednesday          AMERICAN                 MIAMI
# 5              5   634   Thursday            ALASKA                NEWARK
# 6              6  2578   Saturday           JETBLUE            LONG BEACH
# 7              8  2592   Saturday        AEROMEXICO           MEXICO CITY
# 8              9   919     Friday        AIR CANADA               TORONTO
# 9             10  3028    Tuesday            UNITED              PORTLAND
# 10            11  1129    Tuesday         SOUTHWEST             SAN DIEGO
# 11            12  2648   Saturday           JETBLUE                BOSTON
# 12            13  3104    Tuesday            UNITED               SPOKANE
# 13            14  2589   Saturday          INTERJET           GUADALAJARA
# 14            15  2345    Tuesday             DELTA  MINNEAPOLIS-ST. PAUL
# 15            16   390     Friday            ALASKA           LOS ANGELES
# 16            17   954    Tuesday            ALASKA          NEW YORK-JFK
# 17            18  2913     Friday  TURKISH AIRLINES              ISTANBUL
# 18            19   803     Sunday            ALASKA             BALTIMORE
# 19            20   767   Thursday        AIR CANADA               TORONTO
# 20            21  1214    Tuesday         SOUTHWEST             LAS VEGAS
# 21            22  1373    Tuesday       UNITED INTL              SHANGHAI
# 22            23  1263   Thursday       UNITED INTL          TOKYO-NARITA
# 23            24  2723  Wednesday    AIR FRANCE/KLM       PARIS-DE GAULLE
# 24            25  3097    Tuesday            UNITED               SPOKANE
# 25            27   214  Wednesday          AMERICAN           LOS ANGELES
# 26            28  1372    Tuesday       UNITED INTL       PARIS-DE GAULLE
# 27            29  1956    Tuesday            UNITED                BOSTON
# 28            30  1716     Sunday    AIR FRANCE/KLM       PARIS-DE GAULLE
# 29            31  1487  Wednesday      HAWAIIAN AIR              HONOLULU
# ...          ...   ...        ...               ...                   ...
# 2447        2777  1996    Tuesday            UNITED             BALTIMORE
# 2448        2778  2708  Wednesday    AIR FRANCE/KLM       PARIS-DE GAULLE
# 2449        2780  1744   Saturday    CATHAY PACIFIC             HONG KONG
# 2450        2781  2843    Tuesday            UNITED               SEATTLE
# 2451        2782  1772   Thursday          AMERICAN        CHICAGO-O'HARE
# 2452        2783   338     Friday            ALASKA             SAN DIEGO
# 2453        2784   366     Friday         LUFTHANSA             FRANKFURT
# 2454        2785  1179   Thursday             DELTA          NEW YORK-JFK
# 2455        2786  1947   Saturday    AIR FRANCE/KLM       PARIS-DE GAULLE
# 2456        2787  1305    Tuesday       UNITED INTL       LONDON HEATHROW
# 2457        2788  3196   Thursday             DELTA           LOS ANGELES
# 2458        2789   976     Friday         LUFTHANSA                MUNICH
# 2459        2791   777   Thursday       UNITED INTL     SAN JOSE DEL CABO
# 2460        2792  2171  Wednesday          FRONTIER                DENVER
# 2461        2793  2570    Tuesday            UNITED        CHICAGO-O'HARE
# 2462        2794  3007  Wednesday          AMERICAN                 MIAMI
# 2463        2795   820     Sunday            ALASKA              PORTLAND
# 2452        West US       Medium   Gates 50-59  2018-12-31     126.0
# 2453         Europe          Hub  Gates 91-102  2018-12-31     180.0
# 2454        East US          Hub   Gates 40-48  2018-12-31     120.0
# 2455         Europe          Hub    Gates 1-12  2018-12-31     185.0
# 2456         Europe          Hub  Gates 91-102  2018-12-31     110.0
# 2457        West US          Hub   Gates 40-48  2018-12-31     105.0
# 2458         Europe          Hub  Gates 91-102  2018-12-31     265.0
# 2459  Canada/Mexico        Small  Gates 91-102  2018-12-31     443.0
# 2460        West US          Hub   Gates 20-39  2018-12-31     108.0
# 2461     Midwest US          Hub   Gates 60-69  2018-12-31     120.0
# 2462        East US          Hub   Gates 50-59  2018-12-31     208.0
# 2463        West US       Medium   Gates 50-59  2018-12-31     170.0
# 2464        West US       Medium   Gates 20-39  2018-12-31      90.0
# 2465        East US          Hub   Gates 50-59  2018-12-31      90.0
# 2466        East US          Hub   Gates 50-59  2018-12-31     105.0
# 2467           Asia          Hub  Gates 91-102  2018-12-31     195.0
# 2468        EAST US        Large   Gates 70-90  2018-12-31     145.0
# 2469           Asia          Hub    Gates 1-12  2018-12-31     380.0
# 2470        West US          Hub   Gates 50-59  2018-12-31     115.0
# 2471     Midwest US       Medium   Gates 70-90  2018-12-31      60.0
# 2472        East US          Hub   Gates 50-59  2018-12-31     280.0
# 2473        West US          Hub   Gates 20-39  2018-12-31     165.0
# 2474        East US          Hub   Gates 70-90  2018-12-31      92.0
# 2475        West US        Small    Gates 1-12  2018-12-31      95.0
# 2476           Asia        Large    Gates 1-12  2018-12-31     220.0
#
#          cleanliness           safety          satisfaction
# 0              Clean          Neutral        Very satisfied
# 1              Clean        Very safe        Very satisfied
# 2            Average    Somewhat safe               Neutral
# 3              Clean        Very safe    Somewhat satsified
# 4     Somewhat clean        Very safe    Somewhat satsified
# 5     Somewhat clean        Very safe        Very satisfied
# 6              Clean        Very safe    Somewhat satsified
# 7     Somewhat clean        Very safe               Neutral
# 8     Somewhat clean    Somewhat safe    Somewhat satsified
# 9            Average        Very safe               Neutral
# 10             Clean        Very safe    Somewhat satsified
# 11    Somewhat clean        Very safe    Somewhat satsified
# 12             Clean        Very safe    Somewhat satsified
# 13    Somewhat clean    Somewhat safe    Somewhat satsified
# 14    Somewhat clean    Somewhat safe    Somewhat satsified
# 15    Somewhat clean          Neutral    Somewhat satsified
# 16             Clean        Very safe        Very satisfied
# 17             Clean        Very safe    Somewhat satsified
# 18             Clean        Very safe        Very satisfied
# 19           Average          Neutral    Somewhat satsified
# 20           Average    Somewhat safe    Somewhat satsified
# 21             Clean        Very safe    Somewhat satsified
# 22           Average          Neutral               Neutral
# 23    Somewhat clean        Very safe    Somewhat satsified
# 24             Clean        Very safe        Very satisfied
# 25           Average    Somewhat safe    Somewhat satsified
# 26    Somewhat clean        Very safe    Somewhat satsified
# 27    Somewhat clean    Somewhat safe    Somewhat satsified
# 28             Clean          Neutral        Very satisfied
# 29             Clean        Very safe    Somewhat satsified
# ...              ...              ...                   ...
# 2447           Clean        Very safe    Somewhat satsified
# 2448  Somewhat clean        Very safe    Somewhat satsified
# 2449  Somewhat clean        Very safe    Somewhat satsified
# 2450  Somewhat clean        Very safe    Somewhat satsified
# 2451           Clean        Very safe    Somewhat satsified
# 2452  Somewhat clean  Somewhat unsafe    Somewhat satsified
# 2453         Average          Neutral    Somewhat satsified
# 2454         Average    Somewhat safe               Neutral
# 2455  Somewhat clean        Very safe    Somewhat satsified
# 2456  Somewhat clean        Very safe    Somewhat satsified
# 2457           Clean        Very safe        Very satisfied
# 2458  Somewhat clean    Somewhat safe    Somewhat satsified
# 2459  Somewhat clean    Somewhat safe    Somewhat satsified
# 2460         Average        Very safe    Somewhat satsified
# 2461           Clean        Very safe        Very satisfied
# 2462           Clean        Very safe        Very satisfied
# 2463         Average          Neutral  Somewhat unsatisfied
# 2464  Somewhat clean    Somewhat safe        Very satisfied
# 2465           Clean        Very safe    Somewhat satsified
# 2466  Somewhat clean        Very safe    Somewhat satsified
# 2467           Clean          Neutral        Very satisfied
# 2468  Somewhat clean    Somewhat safe    Somewhat satsified
# 2469  Somewhat clean    Somewhat safe    Somewhat satsified
# 2470           Clean        Very safe        Very satisfied
# 2471  Somewhat clean  Somewhat unsafe    Somewhat satsified
# 2472  Somewhat clean          Neutral    Somewhat satsified
# 2473           Clean        Very safe        Very satisfied
# 2474           Clean        Very safe        Very satisfied
# 2475           Clean    Somewhat safe        Very satisfied
# 2476           Clean        Very safe    Somewhat satsified
#
# [2477 rows x 13 columns]

# %%
# Find the cleanliness category in airlines not in categories
cat_clean = set(airlines['cleanliness']).difference(categories['cleanliness'])

# Find rows with that category
cat_clean_rows = airlines['cleanliness'].isin(cat_clean)

# Print rows with inconsistent category
print(airlines[cat_clean_rows])

# Print rows with consistent categories only
print(airlines[~cat_clean_rows])

# %%
# Find the cleanliness category in airlines not in categories
cat_clean = set(airlines['cleanliness']).difference(categories['cleanliness'])

# Find rows with that category
cat_clean_rows = airlines['cleanliness'].isin(cat_clean)

# Print rows with inconsistent category
print(airlines[cat_clean_rows])

# Print rows with consistent categories only
print(airlines[~cat_clean_rows])
# Out:
#       Unnamed: 0    id        day           airline           destination  \
# 2              2  2820   Thursday             DELTA           LOS ANGELES
# 9             10  3028    Tuesday            UNITED              PORTLAND
# 19            20   767   Thursday        AIR CANADA               TORONTO
# 20            21  1214    Tuesday         SOUTHWEST             LAS VEGAS
# 22            23  1263   Thursday       UNITED INTL          TOKYO-NARITA
# 25            27   214  Wednesday          AMERICAN           LOS ANGELES
# 31            33   930     Friday        AIR CANADA               TORONTO
# 32            34  3064     Sunday              COPA           PANAMA CITY
# 38            41  2890     Sunday               WOW             REYKJAVIK
# 39            42  3046    Tuesday          AMERICAN           LOS ANGELES
# 42            45  2740  Wednesday    AIR FRANCE/KLM       PARIS-DE GAULLE
# 48            52  1635   Thursday        KOREAN AIR                 SEOUL
# 50            57  1139    Tuesday         SOUTHWEST             SAN DIEGO
# 55            62  1713     Sunday    AIR FRANCE/KLM       PARIS-DE GAULLE
#
# 2447        East US       Medium   Gates 60-69  2018-12-31     110.0
# 2448         Europe          Hub    Gates 1-12  2018-12-31     300.0
# 2449           Asia          Hub    Gates 1-12  2018-12-31     125.0
# 2450        West US          Hub   Gates 70-90  2018-12-31     187.0
# 2451     Midwest US          Hub   Gates 50-59  2018-12-31      85.0
# 2452        West US       Medium   Gates 50-59  2018-12-31     126.0
# 2455         Europe          Hub    Gates 1-12  2018-12-31     185.0
# 2456         Europe          Hub  Gates 91-102  2018-12-31     110.0
# 2457        West US          Hub   Gates 40-48  2018-12-31     105.0
# 2458         Europe          Hub  Gates 91-102  2018-12-31     265.0
# 2459  Canada/Mexico        Small  Gates 91-102  2018-12-31     443.0
# 2461     Midwest US          Hub   Gates 60-69  2018-12-31     120.0
# 2462        East US          Hub   Gates 50-59  2018-12-31     208.0
# 2464        West US       Medium   Gates 20-39  2018-12-31      90.0
# 2465        East US          Hub   Gates 50-59  2018-12-31      90.0
# 2466        East US          Hub   Gates 50-59  2018-12-31     105.0
# 2467           Asia          Hub  Gates 91-102  2018-12-31     195.0
# 2468        EAST US        Large   Gates 70-90  2018-12-31     145.0
# 2469           Asia          Hub    Gates 1-12  2018-12-31     380.0
# 2470        West US          Hub   Gates 50-59  2018-12-31     115.0
# 2471     Midwest US       Medium   Gates 70-90  2018-12-31      60.0
# 2472        East US          Hub   Gates 50-59  2018-12-31     280.0
# 2473        West US          Hub   Gates 20-39  2018-12-31     165.0
# 2474        East US          Hub   Gates 70-90  2018-12-31      92.0
# 2475        West US        Small    Gates 1-12  2018-12-31      95.0
# 2476           Asia        Large    Gates 1-12  2018-12-31     220.0
#
#          cleanliness           safety        satisfaction
# 0              Clean          Neutral      Very satisfied
# 1              Clean        Very safe      Very satisfied
# 3              Clean        Very safe  Somewhat satsified
# 4     Somewhat clean        Very safe  Somewhat satsified
# 5     Somewhat clean        Very safe      Very satisfied
# 6              Clean        Very safe  Somewhat satsified
# 7     Somewhat clean        Very safe             Neutral
# 8     Somewhat clean    Somewhat safe  Somewhat satsified
# 10             Clean        Very safe  Somewhat satsified
# 11    Somewhat clean        Very safe  Somewhat satsified
# 12             Clean        Very safe  Somewhat satsified
# 13    Somewhat clean    Somewhat safe  Somewhat satsified
# 14    Somewhat clean    Somewhat safe  Somewhat satsified
# 15    Somewhat clean          Neutral  Somewhat satsified
# 16             Clean        Very safe      Very satisfied
# 17             Clean        Very safe  Somewhat satsified
# 18             Clean        Very safe      Very satisfied
# 21             Clean        Very safe  Somewhat satsified
# 23    Somewhat clean        Very safe  Somewhat satsified
# 24             Clean        Very safe      Very satisfied
# 26    Somewhat clean        Very safe  Somewhat satsified
# 27    Somewhat clean    Somewhat safe  Somewhat satsified
# 28             Clean          Neutral      Very satisfied
# 29             Clean        Very safe  Somewhat satsified
# 30    Somewhat clean        Very safe  Somewhat satsified
# 33    Somewhat clean        Very safe  Somewhat satsified
# 34             Clean        Very safe             Neutral
# 35    Somewhat clean        Very safe  Somewhat satsified
# 36    Somewhat clean        Very safe      Very satisfied
# 37             Clean        Very safe             Neutral
# ...              ...              ...                 ...
# 2443           Clean          Neutral      Very satisfied
# 2444  Somewhat clean        Very safe  Somewhat satsified
# 2445           Clean        Very safe  Somewhat satsified
# 2446  Somewhat clean        Very safe  Somewhat satsified
# 2447           Clean        Very safe  Somewhat satsified
# 2448  Somewhat clean        Very safe  Somewhat satsified
# 2449  Somewhat clean        Very safe  Somewhat satsified
# 2450  Somewhat clean        Very safe  Somewhat satsified
# 2451           Clean        Very safe  Somewhat satsified
# 2452  Somewhat clean  Somewhat unsafe  Somewhat satsified
# 2455  Somewhat clean        Very safe  Somewhat satsified
# 2456  Somewhat clean        Very safe  Somewhat satsified
# 2457           Clean        Very safe      Very satisfied
# 2458  Somewhat clean    Somewhat safe  Somewhat satsified
# 2459  Somewhat clean    Somewhat safe  Somewhat satsified
# 2461           Clean        Very safe      Very satisfied
# 2462           Clean        Very safe      Very satisfied
# 2464  Somewhat clean    Somewhat safe      Very satisfied
# 2465           Clean        Very safe  Somewhat satsified
# 2466  Somewhat clean        Very safe  Somewhat satsified
# 2467           Clean          Neutral      Very satisfied
# 2468  Somewhat clean    Somewhat safe  Somewhat satsified
# 2469  Somewhat clean    Somewhat safe  Somewhat satsified
# 2470           Clean        Very safe      Very satisfied
# 2471  Somewhat clean  Somewhat unsafe  Somewhat satsified
# 2472  Somewhat clean          Neutral  Somewhat satsified
# 2473           Clean        Very safe      Very satisfied
# 2474           Clean        Very safe      Very satisfied
# 2475           Clean    Somewhat safe      Very satisfied
# 2476           Clean        Very safe  Somewhat satsified
#
# [2060 rows x 13 columns]

# %%
# Print unique values of both columns
print(airlines['dest_region'].unique())
print(airlines['dest_size'].unique())

# Lower dest_region column and then replace "eur" with "europe"
airlines['dest_region'] = airlines['dest_region'].str.lower() 
airlines['dest_region'] = airlines['dest_region'].replace({'eur':'europe'})
# Out:
# ['Asia' 'Canada/Mexico' 'West US' 'East US' 'Midwest US' 'EAST US'
#  'Middle East' 'Europe' 'eur' 'Central/South America'
#  'Australia/New Zealand' 'middle east']
# ['Hub' 'Small' '    Hub' 'Medium' 'Large' 'Hub     ' '    Small'
#  'Medium     ' '    Medium' 'Small     ' '    Large' 'Large     ']

# %%
# Remove white spaces from `dest_size`
airlines['dest_size'] = airlines['dest_size'].str.strip()

# Verify changes have been effected
print(airlines['dest_region'].unique())
print(airlines['dest_size'].unique())
# Out:
# ['asia' 'canada/mexico' 'west us' 'east us' 'midwest us' 'middle east'
#  'europe' 'central/south america' 'australia/new zealand']
# ['Hub' 'Small' 'Medium' 'Large']

# %%
# Create ranges for categories
label_ranges = [0, 60, 180, np.inf]
label_names = ['short', 'medium', 'long']

# Create wait_type column
airlines['wait_type'] = pd.cut(airlines['wait_min'], bins = label_ranges, 
                                labels = label_names)

# Create mappings and replace
mappings = {'Monday':'weekday', 'Tuesday':'weekday', 'Wednesday': 'weekday', 
            'Thursday': 'weekday', 'Friday': 'weekday', 
            'Saturday': 'weekend', 'Sunday': 'weekend'}

airlines['day_week'] = airlines['day'].replace(mappings)
